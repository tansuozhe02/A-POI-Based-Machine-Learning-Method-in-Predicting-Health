# %% [markdown]
# <a href="https://colab.research.google.com/github/shicong0720/Finding-Healthy-Community-Design-Criteria-with-AI/blob/main/2_17_Combine_all.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import os
import numpy as np
import pandas as pd
import random
from google.colab import drive

# %%
drive.mount('/content/gdrive',force_remount=True)
os.chdir("/content/gdrive/My Drive/big data and city/")
# Out:
# Mounted at /content/gdrive

# %%
data1 = pd.read_csv('CA_heal.csv',header=None)

data1 = np.array(data1, dtype=float)
data1 = pd.DataFrame(data1)
data1
# Out:
#                 0        1     2     3     4   ...    15    16    17   18    19
# 0     1.919532e+06   1137.0   4.8  23.8  17.0  ...  20.2   9.3  28.2  2.3   4.5
# 1     3.935714e+06    341.0  19.4  21.1  18.8  ...  36.0  14.6  35.4  3.1  14.6
# 2     1.501439e+08   7596.0   8.6  22.2  19.4  ...  25.9  12.5  34.3  2.8   8.0
# 3     2.029883e+08  31760.0  25.0  21.8  17.8  ...  41.5  19.1  42.5  3.4  24.0
# 4     1.576429e+07    272.0  11.5  32.3  16.3  ...  29.1  17.8  32.4  4.6  17.0
# ...            ...      ...   ...   ...   ...  ...   ...   ...   ...  ...   ...
# 1464  4.680799e+07   7765.0  11.1  30.5  17.0  ...  28.4  17.2  32.3  4.5  16.4
# 1465  6.467652e+07  65547.0  15.8  23.3  18.4  ...  27.5  15.1  35.0  3.3  15.4
# 1466  1.073409e+08  51359.0  11.7  26.8  18.7  ...  32.7  14.7  35.5  3.2  13.4
# 1467  1.516083e+08  20663.0  11.6  31.7  16.9  ...  34.3  17.5  36.1  4.2  16.7
# 1468  1.111233e+07    705.0   7.2  20.6  22.0  ...  20.9  10.5  29.7  2.1   7.0
#
# ...

# %%
data1.dtypes
# Out:
# 0     float64
# 1     float64
# 2     float64
# 3     float64
# 4     float64
# 5     float64
# 6     float64
# 7     float64
# 8     float64
# 9     float64
# 10    float64
# 11    float64
# 12    float64
# 13    float64
# 14    float64
# 15    float64
# 16    float64
# 17    float64
# 18    float64
# 19    float64
# dtype: object

# %%
data_food = pd.read_csv('food_train.csv',header=None)
data_food = data_food[data_food.columns[0:10]].copy()
data_food2 = pd.read_csv('food_test.csv',header=None)
data_food2 = data_food2[data_food2.columns[0:10]].copy()

# %%
data_health = pd.read_csv('health_train.csv',header=None)
data_health = data_health[data_health.columns[0:10]].copy()
data_health2 = pd.read_csv('health_test.csv',header=None)
data_health2 = data_health2[data_health2.columns[0:10]].copy()

# %%
data_transport = pd.read_csv('transport_train.csv',header=None)
data_transport = data_transport[data_transport.columns[0:14]].copy()
data_transport2 = pd.read_csv('transport_test.csv',header=None)
data_transport2 = data_transport2[data_transport2.columns[0:14]].copy()

# %%
data_community = pd.read_csv('community_train.csv',header=None)
data_community = data_community[data_community.columns[0:18]].copy()
data_community2 = pd.read_csv('community_test.csv',header=None)
data_community2 = data_community2[data_community2.columns[0:18]].copy()

# %%
data_leisure = pd.read_csv('leisure_train.csv',header=None)
data_leisure = data_leisure[data_leisure.columns[0:12]].copy()
data_leisure2 = pd.read_csv('leisure_test.csv',header=None)
data_leisure2 = data_leisure2[data_leisure2.columns[0:12]].copy()

# %%
data_tourism = pd.read_csv('tourism_train.csv',header=None)
data_tourism = data_tourism[data_tourism.columns[0:12]].copy()
data_tourism2 = pd.read_csv('tourism_test.csv',header=None)
data_tourism2 = data_tourism2[data_tourism2.columns[0:12]].copy()

# %%
data_building = pd.read_csv('building_train.csv',header=None)
data_building = data_building[data_building.columns[0:14]].copy()
data_building2 = pd.read_csv('building_test.csv',header=None)
data_building2 = data_building2[data_building2.columns[0:14]].copy()

# %%
data_natural = pd.read_csv('natural_train.csv',header=None)
data_natural = data_natural[data_natural.columns[0:18]].copy()
data_natural2 = pd.read_csv('natural_test.csv',header=None)
data_natural2 = data_natural2[data_natural2.columns[0:18]].copy()

# %%
FOOD = [data_food, data_health,data_transport,data_community,data_leisure,data_tourism,data_building,data_natural]
for i in range(len(FOOD)-1):
  FOOD[0] = pd.merge(FOOD[0], FOOD[i + 1], right_index=True, left_index=True, suffixes = ("_x",'_y'))
FOOD[0]
# Out:
#            0_x  1_x       2_x  3_x       4_x  ...  13_y  14_y  15_y      16_y  17_y
# 0     0.000000    0  0.000000    0  0.000000  ...     0   0.0     0  0.001586    10
# 1     0.000000    0  0.000000    0  0.000000  ...     0   0.0     0  0.000000     0
# 2     0.000000    0  0.000000    0  0.000000  ...     0   0.0     0  0.000000     1
# 3     0.000000    0  0.000000    1  0.027907  ...     0   0.0     0  0.000000     0
# 4     0.000000    0  0.000000    0  0.000000  ...    10   0.0     0  0.000000     0
# ...        ...  ...       ...  ...       ...  ...   ...   ...   ...       ...   ...
# 1195  0.000000    0  0.001612    2  0.000226  ...     0   0.0     0  0.000000     0
# 1196  0.007616    7  0.000000    1  0.004348  ...     0   0.0     0  0.016537     6
# 1197  0.000000    0  0.000000    0  0.000000  ...     0   0.0     0  0.000000     0
# 1198  0.000095    4  0.007759    6  0.000336  ...     0   0.0     0  0.002324     4
# ...

# %%
FOOD2 = [data_food2, data_health2,data_transport2,data_community2,data_leisure2,data_tourism2,data_building2,data_natural2]
for i in range(len(FOOD2)-1):
  FOOD2[0] = pd.merge(FOOD2[0], FOOD2[i + 1], right_index=True, left_index=True, suffixes = ("_x",'_y'))
FOOD2[0]
# Out:
#      0_x  1_x       2_x  3_x       4_x  ...  13_y      14_y  15_y      16_y  17_y
# 0    0.0    0  0.000000    0  0.000000  ...     0  0.000000     0  0.000000     0
# 1    0.0    1  0.004026    9  0.002162  ...     0  0.000000     0  0.001903     5
# 2    0.0    0  0.000000    1  0.000000  ...     0  0.000000     0  0.000000     1
# 3    0.0    0  0.005063    5  0.004288  ...     0  0.009761     2  0.000000     0
# 4    0.0    0  0.000000    0  0.000000  ...     0  0.000000     0  0.000000     0
# ..   ...  ...       ...  ...       ...  ...   ...       ...   ...       ...   ...
# 263  0.0    0  0.000000    1  0.002702  ...     0  0.001920     2  0.000000     0
# 264  0.0    1  0.003607    3  0.003821  ...     0  0.000000     0  0.000000     0
# 265  0.0    0  0.012568    3  0.005586  ...     0  0.000000     0  0.000000     1
# 266  0.0    0  0.000000    1  0.010933  ...     1  0.000000     0  0.000000     0
# ...

# %%
S = FOOD[0].replace(np.nan, 0)
S_test = FOOD2[0].replace(np.nan, 0)

# %%
res = pd.merge(S, data1, right_index=True, left_index=True, suffixes = ("_x",'_y'))
res_test = pd.merge(S_test, data1, right_index=True, left_index=True, suffixes = ("_x",'_y'))
res2 = res.fillna(res.mean())
res2_test = res_test.fillna(res_test.mean())
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4327: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:4536: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA().fit(S)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %%
abs( pca.components_ [0])
# Out:
# array([1.35583079e-07, 1.59261252e-03, 1.57377887e-07, 5.10452921e-03,
#        8.19185660e-08, 1.69995021e-02, 1.18902903e-07, 5.76990541e-03,
#        2.86461572e-07, 4.04088598e-04, 2.90229538e-07, 7.08509183e-04,
#        3.02745940e-07, 6.18626993e-04, 3.61173238e-07, 2.38610318e-04,
#        3.43420353e-07, 5.30417050e-04, 2.41219382e-07, 1.14699843e-03,
#        1.67246495e-07, 4.15547029e-03, 5.74198248e-08, 3.48885342e-02,
#        2.41529156e-07, 1.05439467e-03, 1.44805423e-07, 3.87422615e-03,
#        1.66219034e-08, 5.27916333e-02, 1.03706269e-07, 5.31015226e-03,
#        6.90528459e-08, 3.06900059e-03, 7.74762370e-08, 1.15537227e-02,
#        4.04165498e-07, 4.71828795e-04, 3.72183169e-07, 5.78993885e-04,
#        3.12278486e-07, 1.31516305e-03, 2.75633368e-07, 8.59350267e-04,
#        2.04813576e-07, 1.00411553e-03, 2.33968042e-07, 3.22786012e-03,
#        1.79841957e-07, 1.96582074e-03, 4.13726376e-07, 3.04339906e-04,
# ...

# %%
result = []
for i in range(len(pca.components_)):
  if pca.components_ [0][i]> 1.0e-02:
    result.append(i)
result
# Out:
# [5, 23, 29, 35, 57, 63, 77, 79, 81, 83, 89, 91]

# %%
result2 = []
for i in range(len(pca.components_)):
  if pca.components_ [0][i]< 1.0e-03 and i%2 != 0:
    result2.append(i)
result2
# Out:
# [9, 11, 13, 15, 17, 37, 39, 43, 51, 59, 67, 69, 71, 75, 85, 97, 101, 103, 105]

# %%
res2 = res.iloc[:,result].copy()
res2_test = res_test.iloc[:,result].copy()

# %%
res3 = pd.merge(res2, data1, right_index=True, left_index=True, suffixes = ("_x",'_y'))
res3_test = pd.merge(res2_test, data1, right_index=True, left_index=True, suffixes = ("_x",'_y'))
res3 = res3.fillna(res3.mean())
res4 = res3.drop([5, 6], axis = 1)
res3_test = res3_test.fillna(res3_test.mean())
res4_test = res3_test.drop([5, 6], axis = 1)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4327: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:4536: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
res4.to_csv('combine_train.csv', header=False, index=False)

# %%
res4_test.to_csv('combine_test.csv', header=False, index=False)

# %%
X_train = res3.iloc[:,:12]
X_test = res3_test.iloc[:,:12]
y_train = res3.iloc[:,13]
y_test = res3_test.iloc[:,13]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
X_train, y_train = make_regression(n_features=12, random_state=0, shuffle=False)
regr = RandomForestRegressor(max_depth=2, random_state=0)
regr.fit( X_train, y_train )
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=2, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=0, verbose=0, warm_start=False)

# %%
from sklearn import model_selection
cv_score = model_selection.cross_val_score(regr, X_train, y_train, cv=5)
cv_score
# Out:
# array([0.30520819, 0.36029062, 0.15886937, 0.36782255, 0.27065505])

# %%
from sklearn.model_selection import GridSearchCV
parameters = {
    'n_estimators' : [60,80,100],
    'max_depth': [1,5,10]
}
Grid_RF = GridSearchCV(RandomForestRegressor(random_state=41),parameters, cv=5)
Grid_RF.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=False, random_state=41,
#                                              verbose=0, warm_start=False),
# ...

# %%
best_RF_model = Grid_RF.best_estimator_

# %%
best_RF_model
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=10, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=41, verbose=0, warm_start=False)

# %%
cv_score = model_selection.cross_val_score(best_RF_model, X_train, y_train, cv=5)
cv_score
# Out:
# array([0.39066712, 0.49721216, 0.3204634 , 0.50079144, 0.56385462])
